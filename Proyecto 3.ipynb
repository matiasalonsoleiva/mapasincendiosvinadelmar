# %%
import folium
# !pip install folium

# %%
from folium.plugins import MiniMap

# %%
popuptext="<b> Viña del Mar </b> - Matías A. Leiva M."

vina = folium.Map(location=[-33.0245186,-71.5539944], zoom_start = 14)
folium.Marker(location=[-33.0245186,-71.5539944], popup = popuptext ).add_to(vina)

popuptext2 ="<b> Quinta Vergara </b> - Matías A. Leiva M."
folium.Marker(location=[-33.0280766,-71.5570067], popup = popuptext2).add_to(vina)
folium.Circle(location=[-33.0280766,-71.5570067], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)


popuptext3 = "<b> Población Puerto Montt </b> - Matías A. Leiva M."
folium.Marker(location=[-33.0434097,-71.5487682], popup = popuptext3 ).add_to(vina)
folium.Circle(location=[-33.0434097,-71.5487682], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)


popuptext4 = "<b> Población Puerto Aysén </b> - Matías A. Leiva M."
folium.Marker(location=[-32.9811891,-71.5292406], popup = popuptext4 ).add_to(vina)
folium.Circle(location=[-32.9811891,-71.5292406], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)


popuptext5 = "<b> Nueva Esperanza 2000 </b> - Matías A. Leiva M."
folium.Marker(location=[-33.0007732,-71.5070109], popup = popuptext5).add_to(vina)
folium.Circle(location=[-33.0007732,-71.5070109], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)

popuptext6 = "<b> Rodelillo </b> - Matías A. Leiva M."
folium.Marker(location=[-33.0600707,-71.5684667], popup = popuptext6).add_to(vina)
folium.Circle(location=[-33.0600707,-71.5684667], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)

popuptext7 = "<b> Felipe Camiroaga </b> - Matías A. Leiva M."
folium.Marker(location=[-33.0506063,-71.5490289,], popup = popuptext7).add_to(vina)
folium.Circle(location=[-33.0506063,-71.5490289,], color = 'red', fill_color = 'red', radius= 60, weight = 4, fill_opacity = 0.5).add_to(vina)

vina
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.5.1/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...
